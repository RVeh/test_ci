# %% [markdown]
# ### Ziel
# Sichtbarmachen der Form und Streuung des Binomialmodells
# in einem $\sigma$-basierten Darstellungsbereich um $\mu$.
#
# ### Eingabe
#
# - n  : Stichprobenumfang
# - p  : Erfolgswahrscheinlichkeit
#
# ### Ausführen
# Beim ersten Start bitte **Run All Cells** ausführen.
# Parameter im Code anpassen.
#
# Danach: Die Zellen *Modell* sowie *Plot und ggf. Grafik speichern* ausführen: **Run (▶)**.
#
# Die Zelle *Imports* muss nur einmal ausgeführt werden.

# %%
# ======== Imports ============
from tests.model.binomial import BinomialModel
from tests.plots.plot_model import (plot_binomial_model, ModelPlotStyle)

# %%
# =============== Modell =========================
n  = 100
p0 = 0.4

# %%
# ========= Plot und ggf. Grafik speichern =========
model = BinomialModel(n=n, p=p0)

style = ModelPlotStyle(
    bar_color="tab:blue", bar_width=5,
    mean_color="gray", mean_style="--", mean_width=1.5,
    sigma_range=5.0,   # ± kσ um μ
)

plot_binomial_model(
    model=model,
    style=style,
    #save=f"BinModell_n{n}_p{p0:.2f}.pdf"
);
