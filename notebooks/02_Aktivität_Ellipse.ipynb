# %% [markdown]
# **Arbeitsauftrag (Beispiel):**
#
# - Zeichnen Sie zu einem gegebenen Stichprobenergebnis $h$
#   das zugehörige Konfidenzintervall ein.
# - Markieren Sie alternativ ein festes $p$ und konstruieren Sie
#   das Prognoseintervall.

# %%
import setup_path
from lib.intervalle import (
        plot_ci, CIConfig, 
        IntervalGeometry, CIStyle
)

# %%
model = CIConfig(
    n=50,
    gamma=0.95
)

geometry = IntervalGeometry(
    x_min=0.0,
    x_max=1.0,
)

style = CIStyle(
    curve_upper = "gray",
    curve_lower = "gray",
    grid = True,
)

plot_ci(model, geometry, style,show_interval=False);
